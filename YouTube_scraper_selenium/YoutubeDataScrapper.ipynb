# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = 'https://www.youtube.com/c/AlexTheAnalyst/videos'

video_urls = []
video_titles = []
video_views = []
video_upload_times = []
video_counts_temp = []

# %%
def get_video_urls(url):
    
    print('Process has been started...\n')
    path = './chromedriver111.exe' # selenium web driver path
    driver = webdriver.Chrome(executable_path=path)
    driver.get(url)

    # scrolling to the bottom of the page
    for item in range(50):
        page = driver.find_element_by_tag_name('html')
        page.send_keys(Keys.END)
        
    # extracting data from page
    content = driver.page_source.encode('utf-8').strip()
    soup = BeautifulSoup(content, 'html.parser')
    
    # extracting views and time
    print('Extracting video views and time...\n')
    for views in soup.findAll('span', class_='style-scope ytd-grid-video-renderer'):
        video_counts_temp.append(views.get_text())

    # extracting and printing youtube video url from channel
    print('Extracting video titles and urls...\n')
    for url in soup.findAll('a', id='video-title'):
        video_urls.append('https://www.youtube.com' + url.get('href')) 
        video_titles.append(url.get('title'))
        
    video_views = video_counts_temp[0::2]
    video_upload_times = video_counts_temp[1::2]    

    print('Printing results...\n')
    print(f'This youtube channel has {len(video_urls)} videos published')
    
    data = pd.DataFrame(list(zip(video_titles, video_views, video_upload_times, video_urls)), columns =['Titles', 'Views', 'Upload Time', 'Links']) 
    print('Process has been completed...\n')
    
    driver.quit()
    return data

if __name__ == '__main__':
    df = get_video_urls(url)
# Out:
# Process has been started...
#
# Extracting video views and time...
#
# Extracting video titles and urls...
#
# Printing results...
#
# This youtube channel has 114 videos published
# Process has been completed...

# %%
df.sample(15)
# Out:
#                                                Titles       Views  \
# 52                     Data Analyst Q/A LIVE #5 | AMA  2.3K views
# 65          Top 10 Coursera Courses for Data Analysts   45K views
# 41  Best Industries for Data Analysts in 2021 | Al...  7.6K views
# 3           How NOT to Become a Data Analyst (Funny?)   11K views
# 42              Top 5 Data Analyst Interview Mistakes  8.7K views
# 56  What is No Code Analytics? | Alex The Analyst ...  2.5K views
# 40                          Top 5 Data Analyst Skills   14K views
# 21  Data Analyst Q/A #6 | Why Am I Not a Data Scie...   13K views
# 34  Advanced SQL Tutorial | String Functions + Use...   11K views
# 10  Why You Need to Stop Taking Courses (From an E...  114K views
# 9   When To Start Applying To Your First Data Anal...   25K views
# 97  Intermediate SQL Tutorial | Inner/Outer Joins ...   36K views
# 23  Data Analyst Reacts: How to Go From Data Analy...   15K views
# 11         How to Create a Portfolio Website for FREE   23K views
# 61  Asking My Wife Your Questions About Me | Alex ...  7.1K views
#
#                Upload Time                                        Links
# 52  Streamed 10 months ago  https://www.youtube.com/watch?v=MQ5UUNjWgug
# 65           11 months ago  https://www.youtube.com/watch?v=mLUzFXPPa4I
# 41            9 months ago  https://www.youtube.com/watch?v=tJaDicmRW7s
# 3              1 month ago  https://www.youtube.com/watch?v=465x3JmMJYU
# 42            9 months ago  https://www.youtube.com/watch?v=hfRcaRw_atI
# 56           10 months ago  https://www.youtube.com/watch?v=GGLF2jLo8J4
# 40            8 months ago  https://www.youtube.com/watch?v=T3KMZoXrVTQ
# 21            5 months ago  https://www.youtube.com/watch?v=IZRe0nwkuXc
# 34            8 months ago  https://www.youtube.com/watch?v=GQj6_6V_jVA
# 10            2 months ago  https://www.youtube.com/watch?v=aLp-6C-p-T0
# 9             2 months ago  https://www.youtube.com/watch?v=UGF49YZZRNc
# 97              1 year ago  https://www.youtube.com/watch?v=9URM1_2S0ho
# 23            6 months ago  https://www.youtube.com/watch?v=qewHAdfzLOw
# 11            3 months ago  https://www.youtube.com/watch?v=ocdwh0KYeUs
# 61           11 months ago  https://www.youtube.com/watch?v=brxnKIy6Cek

# %%
df.to_excel("output.xlsx", index=False)
